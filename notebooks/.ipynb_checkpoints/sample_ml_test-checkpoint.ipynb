# %%
from collections import deque
from pandas import DataFrame as df
from pandas import Series
from sklearn import linear_model
from sklearn.neighbors import KNeighborsClassifier

import datetime as dt
import numpy as np
import pandas as pd

myprices = deque([206.56, 205.34, 205.03, 204.89, 204.73, 205.25, 205.525,
                  203.23, 203.03, 202.7], maxlen=10)

mytimes = deque([dt.datetime(2015, 1, 2, 14, 58, 0),
                 dt.datetime(2015, 1, 2, 15, 58, 0),
                 dt.datetime(2015, 1, 2, 16, 58, 0),
                 dt.datetime(2015, 1, 2, 17, 58, 0),
                 dt.datetime(2015, 1, 2, 18, 58, 0),
                 dt.datetime(2015, 1, 2, 19, 58, 0),
                 dt.datetime(2015, 1, 2, 20, 58, 0),
                 dt.datetime(2015, 1, 5, 14, 58, 0),
                 dt.datetime(2015, 1, 5, 15, 58, 0),
                 dt.datetime(2015, 1, 5, 16, 58, 0)], maxlen=10)

datep_df = df([list(mytimes)]).T
datep_df.columns = ['pdate']
datep_df['cp'] = list(myprices)
datep_df_sorted = datep_df.sort('pdate')
cp = list(datep_df_sorted['cp']) # current price

cp
# Out:
# [206.56,
#  205.34,
#  205.03,
#  204.88999999999999,
#  204.72999999999999,
#  205.25,
#  205.52500000000001,
#  203.22999999999999,
#  203.03,
#  202.69999999999999]

# %%
datep_df
# Out:
#                 pdate       cp
# 0 2015-01-02 14:58:00  206.560
# 1 2015-01-02 15:58:00  205.340
# 2 2015-01-02 16:58:00  205.030
# 3 2015-01-02 17:58:00  204.890
# 4 2015-01-02 18:58:00  204.730
# 5 2015-01-02 19:58:00  205.250
# 6 2015-01-02 20:58:00  205.525
# 7 2015-01-05 14:58:00  203.230
# 8 2015-01-05 15:58:00  203.030
# 9 2015-01-05 16:58:00  202.700

# %%
hc = 2
x1 = hc*[cp[0]]
x1.extend(cp[:-hc])
datep_df['x1'] = x1

# %%
datep_df
# Out:
#                 pdate       cp       x1
# 0 2015-01-02 14:58:00  206.560  206.560
# 1 2015-01-02 15:58:00  205.340  206.560
# 2 2015-01-02 16:58:00  205.030  206.560
# 3 2015-01-02 17:58:00  204.890  205.340
# 4 2015-01-02 18:58:00  204.730  205.030
# 5 2015-01-02 19:58:00  205.250  204.890
# 6 2015-01-02 20:58:00  205.525  204.730
# 7 2015-01-05 14:58:00  203.230  205.250
# 8 2015-01-05 15:58:00  203.030  205.525
# 9 2015-01-05 16:58:00  202.700  203.230

# %%
x2 = 2*hc*[cp[0]]
x2.extend(cp[:-(2*hc)])
datep_df['x2'] = x2

x3 = 3*hc*[cp[0]]
x3.extend(cp[:-(3*hc)])
datep_df['x3'] = x3

datep_df
# Out:
#                 pdate       cp       x1      x2      x3
# 0 2015-01-02 14:58:00  206.560  206.560  206.56  206.56
# 1 2015-01-02 15:58:00  205.340  206.560  206.56  206.56
# 2 2015-01-02 16:58:00  205.030  206.560  206.56  206.56
# 3 2015-01-02 17:58:00  204.890  205.340  206.56  206.56
# 4 2015-01-02 18:58:00  204.730  205.030  206.56  206.56
# 5 2015-01-02 19:58:00  205.250  204.890  205.34  206.56
# 6 2015-01-02 20:58:00  205.525  204.730  205.03  206.56
# 7 2015-01-05 14:58:00  203.230  205.250  204.89  205.34
# 8 2015-01-05 15:58:00  203.030  205.525  204.73  205.03
# 9 2015-01-05 16:58:00  202.700  203.230  205.25  204.89

# %%
datep_df['x1'] = datep_df['cp']/datep_df['x1'] - len(cp)*[1.0]

# %%
datep_df
# Out:
#                 pdate       cp        x1      x2      x3
# 0 2015-01-02 14:58:00  206.560  0.000000  206.56  206.56
# 1 2015-01-02 15:58:00  205.340 -0.005906  206.56  206.56
# 2 2015-01-02 16:58:00  205.030 -0.007407  206.56  206.56
# 3 2015-01-02 17:58:00  204.890 -0.002191  206.56  206.56
# 4 2015-01-02 18:58:00  204.730 -0.001463  206.56  206.56
# 5 2015-01-02 19:58:00  205.250  0.001757  205.34  206.56
# 6 2015-01-02 20:58:00  205.525  0.003883  205.03  206.56
# 7 2015-01-05 14:58:00  203.230 -0.009842  204.89  205.34
# 8 2015-01-05 15:58:00  203.030 -0.012140  204.73  205.03
# 9 2015-01-05 16:58:00  202.700 -0.002608  205.25  204.89

# %%
hc = 2
x1 = hc*[cp[0]]
x1.extend(cp[:-hc])
datep_df['x1'] = x1

x2 = 2*hc*[cp[0]]
x2.extend(cp[:-(2*hc)])
datep_df['x2'] = x2

x3 = 3*hc*[cp[0]]
x3.extend(cp[:-(3*hc)])
datep_df['x3'] = x3

datep_df
# Out:
#                 pdate       cp       x1      x2      x3
# 0 2015-01-02 14:58:00  206.560  206.560  206.56  206.56
# 1 2015-01-02 15:58:00  205.340  206.560  206.56  206.56
# 2 2015-01-02 16:58:00  205.030  206.560  206.56  206.56
# 3 2015-01-02 17:58:00  204.890  205.340  206.56  206.56
# 4 2015-01-02 18:58:00  204.730  205.030  206.56  206.56
# 5 2015-01-02 19:58:00  205.250  204.890  205.34  206.56
# 6 2015-01-02 20:58:00  205.525  204.730  205.03  206.56
# 7 2015-01-05 14:58:00  203.230  205.250  204.89  205.34
# 8 2015-01-05 15:58:00  203.030  205.525  204.73  205.03
# 9 2015-01-05 16:58:00  202.700  203.230  205.25  204.89

# %%
datep_df['x1'] = datep_df['cp']/datep_df['x1'] - np.ones(len(cp))
datep_df['x2'] = datep_df['cp']/datep_df['x2'] - np.ones(len(cp))
datep_df['x3'] = datep_df['cp']/datep_df['x3'] - np.ones(len(cp))

datep_df
# Out:
#                 pdate       cp        x1        x2        x3
# 0 2015-01-02 14:58:00  206.560  0.000000  0.000000  0.000000
# 1 2015-01-02 15:58:00  205.340 -0.005906 -0.005906 -0.005906
# 2 2015-01-02 16:58:00  205.030 -0.007407 -0.007407 -0.007407
# 3 2015-01-02 17:58:00  204.890 -0.002191 -0.008085 -0.008085
# 4 2015-01-02 18:58:00  204.730 -0.001463 -0.008859 -0.008859
# 5 2015-01-02 19:58:00  205.250  0.001757 -0.000438 -0.006342
# 6 2015-01-02 20:58:00  205.525  0.003883  0.002414 -0.005011
# 7 2015-01-05 14:58:00  203.230 -0.009842 -0.008102 -0.010276
# 8 2015-01-05 15:58:00  203.030 -0.012140 -0.008304 -0.009755
# 9 2015-01-05 16:58:00  202.700 -0.002608 -0.012424 -0.010689

# %%
leadx = cp[hc:]
leadx.extend(hc*[cp[-1]])
datep_df['lead'] = leadx
datep_df['n1g'] = (datep_df['lead']/datep_df['cp'] - np.ones(len(cp))) > 0
datep_df
# Out:
#                 pdate       cp        x1        x2        x3     lead    n1g
# 0 2015-01-02 14:58:00  206.560  0.000000  0.000000  0.000000  205.030  False
# 1 2015-01-02 15:58:00  205.340 -0.005906 -0.005906 -0.005906  204.890  False
# 2 2015-01-02 16:58:00  205.030 -0.007407 -0.007407 -0.007407  204.730  False
# 3 2015-01-02 17:58:00  204.890 -0.002191 -0.008085 -0.008085  205.250   True
# 4 2015-01-02 18:58:00  204.730 -0.001463 -0.008859 -0.008859  205.525   True
# 5 2015-01-02 19:58:00  205.250  0.001757 -0.000438 -0.006342  203.230  False
# 6 2015-01-02 20:58:00  205.525  0.003883  0.002414 -0.005011  203.030  False
# 7 2015-01-05 14:58:00  203.230 -0.009842 -0.008102 -0.010276  202.700  False
# 8 2015-01-05 15:58:00  203.030 -0.012140 -0.008304 -0.009755  202.700  False
# 9 2015-01-05 16:58:00  202.700 -0.002608 -0.012424 -0.010689  202.700  False

# %%
n1g = leadx/cp - ones(len(cp))
n1g
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-10901f62345b> in <module>()
# ----> 1 n1g = leadx/cp - ones(len(cp))
#       2 n1g
#
# TypeError: unsupported operand type(s) for /: 'list' and 'list'
